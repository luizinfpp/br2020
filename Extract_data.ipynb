# %% [markdown]
# <a href="https://colab.research.google.com/github/luizinfpp/br2020/blob/Data-Extraction/Extract_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading files with raw data extracted from html

# %% [markdown]
# ATTENTION: The match Flamengo X Red Bull Bragantino (Oct 16, 2020) is not in the data file.

# %%
import pandas as pd
